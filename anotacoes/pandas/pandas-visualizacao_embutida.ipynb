# %%
from os import path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('bmh')
import seaborn as sns
# %matplotlib inline

# %%
path_sourcedir = '/home/jonatasleon/Workspace/data-science-py/apostilas/3. Python para Visualização de dados/Visualização de dados incorporada do Pandas'
path_df1 = path.join(path_sourcedir, 'df1.csv')
path_df2 = path.join(path_sourcedir, 'df2.csv')

# %%
df1 = pd.read_csv(path_df1, index_col=0)
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv(path_df2, float_precision='high')
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist()

# %%
df2.plot.area(alpha=0.4).legend(facecolor='g', loc='best', framealpha=.3)

# %%
df2.plot.bar(stacked=True).legend(facecolor='g', loc='best', framealpha=.3)

# %%
df1['A'].plot.hist(bins=50)

# %%
df1.plot.line(x=df1.index, y='B', figsize=(12, 5), lw=1).legend(facecolor='b', loc='best', framealpha=.2)

# %%
df1.plot.scatter(x='A', y='B', s=df1['C']*50).legend(facecolor='b', loc='best', framealpha=.2)
# Out:
# /home/jonatasleon/.virtualenvs/jupyter/lib/python3.5/site-packages/matplotlib/collections.py:853: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# No handles with labels found to put in legend.

# %%
df2.plot.box()

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['A', 'B'])

# %%
df.plot.hexbin(x='A', y='B', gridsize=20)

# %%
df.plot.hist('A')

# %%
df2.plot.kde()
