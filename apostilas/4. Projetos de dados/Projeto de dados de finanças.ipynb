# %% [markdown]
# # Projeto de dados do mercado financeiro
#
# Neste projeto de dados, nos concentraremos na análise de dados exploratórios dos preços das ações. Tenha em mente que este projeto apenas pretende praticar suas habilidades de visualização e pandas, não é para ser uma análise financeira robusta ou ser tomado como um conselho financeiro.
# ____
# ** NOTA: Este projeto é extremamente desafiador, porque irá introduzir muitos novos conceitos e te fará procurar as coisas por conta própria (vamos apontar você na direção certa) para tentar resolver as tarefas emitidas. Sinta-se à vontade para passar pelo livro de conferências de soluções e no vídeo como um projeto "passo a passo" se você não quer ter que procurar as coisas sozinho. Você ainda aprenderá muito dessa forma! **
# ____
# Vamos nos concentrar nas ações dos banco e ver como eles performaram durante a [crise financeira](https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%9308) até o início de 2016.

# %% [markdown]
# ## Obter dados
#
# Nesta seção, aprenderemos a usar pandas para ler diretamente os dados das finanças do Google usando pandas!
#
# Primeiro, precisamos começar com as importações adequadas, que já apresentamos para você aqui.
#
# * Nota: [Você precisará instalar pandas-datareader para que isso funcione!](Https://github.com/pydata/pandas-datareader) O datareader Pandas permite que você [leia informações das ações diretamente da internet](http://pandas.pydata.org/pandas-docs/stable/remote_data.html) Use estes links para orientação de instalação (** pip install pandas-datareader **), ou simplesmente acompanhe a conferência de vídeo. *
#
# ### Os Imports
#
# Já preenchidos para você.

# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime

import seaborn as sns
sns.set(style='whitegrid')
# %matplotlib inline

# %% [markdown]
# ## Dados
#
# Precisamos obter dados usando o datareader de pandas. Obteremos informações sobre ações para os seguintes bancos:
# * Bank of America
# * CitiGroup
# * Goldman Sachs
# * JPMorgan Chase
# * Morgan Stanley
# * Wells Fargo
#
# ** Descubra como obter os dados de ações de 1 de janeiro de 2006 a 1º de janeiro de 2016 para cada um desses bancos. Defina cada banco como um dataframe separado, com o nome da variável para que esse banco seja seu símbolo de ticker. Isso envolverá algumas etapas: **
# 1. Use datetime para definir objetos de início e fim de data e hora.
# 2. Descobrir o símbolo do ticker para cada banco.
# 2. Descubra como usar o datareader para pegar as cotações.
#
# ** Use [esta página de documentação](http://pandas.pydata.org/pandas-docs/stable/remote_data.html) para obter dicas e instruções. Use o google finance como um fonte, por exemplo: **
#
#      # Banco da América
#      BAC = data.DataReader ("BAC", "google", início e fim)

# %%
inicio = datetime.date(2006, 1, 1)
fim = datetime.date(2016, 1, 1)

# %%
BAC = data.DataReader('BAC', 'morningstar', start=inicio, end=fim)
BAC.index = BAC.index.droplevel()
BAC.head()
# Out:
#             Close   High    Low   Open    Volume
# Date
# 2006-01-02  46.15  46.36  45.91  46.02         0
# 2006-01-03  47.08  47.18  46.15  46.92  16197900
# 2006-01-04  46.58  47.24  46.45  47.00  17427400
# 2006-01-05  46.64  46.83  46.32  46.58  14668900
# 2006-01-06  46.57  46.91  46.35  46.80  11965700

# %%
C = data.DataReader('C', 'morningstar', start=inicio, end=fim)
C.index = C.index.droplevel()
C.head()
# Out:
#             Close   High    Low   Open   Volume
# Date
# 2006-01-02  485.3  487.1  482.2  483.5        0
# 2006-01-03  492.9  493.8  481.1  490.0  1536700
# 2006-01-04  483.8  491.0  483.5  488.6  1852790
# 2006-01-05  486.2  487.8  484.0  484.4  1015470
# 2006-01-06  486.2  489.0  482.0  488.8  1358930

# %%
GS = data.DataReader('GS', 'morningstar', start=inicio, end=fim)
GS.index = GS.index.droplevel()
GS.head()
# Out:
#              Close    High     Low    Open   Volume
# Date
# 2006-01-02  127.71  128.07  126.70  127.15        0
# 2006-01-03  128.87  129.44  124.23  126.70  6168700
# 2006-01-04  127.09  128.91  126.38  127.35  4834700
# 2006-01-05  127.04  127.32  125.61  126.00  3688100
# 2006-01-06  128.84  129.25  127.29  127.29  4249100

# %%
JPM = data.DataReader('JPM', 'morningstar', start=inicio, end=fim)
JPM.index = JPM.index.droplevel()
JPM.head()
# Out:
#             Close   High    Low   Open    Volume
# Date
# 2006-01-02  39.69  39.79  39.48  39.71         0
# 2006-01-03  40.19  40.36  39.30  39.83  12838000
# 2006-01-04  39.62  40.14  39.42  39.78  11836800
# 2006-01-05  39.74  39.81  39.50  39.61   7658700
# 2006-01-06  40.02  40.24  39.55  39.92   7812700

# %%
MS = data.DataReader('MS', 'morningstar', start=inicio, end=fim)
MS.index = MS.index.droplevel()
MS.head()
# Out:
#               Close     High      Low     Open   Volume
# Date
# 2006-01-02  47.1008  47.3333  46.7107  47.2751        0
# 2006-01-03  48.4041  48.5535  47.1008  47.4578  6354408
# 2006-01-04  48.4373  49.2093  48.4373  48.7278  9292188
# 2006-01-05  48.5701  48.6365  48.1634  48.6033  6534262
# 2006-01-06  48.6199  48.8524  48.1883  48.7860  8146445

# %%
WFC = data.DataReader('WFC', 'morningstar', start=inicio, end=fim)
WFC.index = WFC.index.droplevel()
WFC.head()
# Out:
#              Close    High     Low    Open    Volume
# Date
# 2006-01-02  31.415  31.535  31.215  31.415         0
# 2006-01-03  31.900  31.975  31.195  31.600  11015000
# 2006-01-04  31.530  31.820  31.365  31.800  10594000
# 2006-01-05  31.495  31.555  31.310  31.500   9927600
# 2006-01-06  31.680  31.775  31.385  31.580   8324000

# %%
df = data.DataReader(['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC'], 'morningstar', inicio, fim)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 15660 entries, (BAC, 2006-01-02 00:00:00) to (WFC, 2016-01-01 00:00:00)
# Data columns (total 5 columns):
# Close     15660 non-null float64
# High      15660 non-null float64
# Low       15660 non-null float64
# Open      15660 non-null float64
# Volume    15660 non-null int64
# dtypes: float64(4), int64(1)
# memory usage: 678.1+ KB

# %% [markdown]
# ** Crie uma lista dos símbolos dos tickers (como strings) em ordem alfabética. Chame esta lista: tickers **

# %%
tickers = ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %% [markdown]
# ** Use pd.concat para concatenar os DataFrames do banco juntos em um único chamado bank_stocks. Defina o argumento das chaves igual à lista de tickers. Também preste atenção em que eixo você concatena. **

# %%
bank_stocks = pd.concat([BAC, C, GS, JPM, MS, WFC], axis=1, keys=tickers)
bank_stocks
# Out:
#               BAC                                          C            \
#             Close     High     Low   Open     Volume   Close      High
# Date
# 2006-01-02  46.15  46.3600  45.910  46.02          0  485.30  487.1000
# 2006-01-03  47.08  47.1800  46.150  46.92   16197900  492.90  493.8000
# 2006-01-04  46.58  47.2400  46.450  47.00   17427400  483.80  491.0000
# 2006-01-05  46.64  46.8300  46.320  46.58   14668900  486.20  487.8000
# 2006-01-06  46.57  46.9100  46.350  46.80   11965700  486.20  489.0000
# 2006-01-09  46.60  46.9700  46.360  46.72   15536300  483.90  487.4000
# 2006-01-10  46.21  46.5100  45.880  46.40   15507500  485.40  485.5000
# 2006-01-11  46.10  46.2500  45.750  46.06   14562000  489.80  495.8000
# 2006-01-12  45.80  46.2300  45.710  46.22   10394900  490.30  491.0000
# 2006-01-13  45.80  46.0000  45.680  45.83   10742100  489.20  491.9000
# 2006-01-16  45.80  46.0000  45.680  45.83          0  489.20  491.9000
# 2015-12-22  31.9600  11468401  54.340  54.5000  53.700  54.360  10318062
# 2015-12-23  32.4700   6807062  55.040  55.0600  54.460  54.600  13033579
# 2015-12-24  32.5700   2798163  54.820  55.0900  54.710  54.970   4999417
# 2015-12-25  32.4800         0  54.820  54.8200  54.820  54.820         0
# 2015-12-28  32.3600   5420280  54.680  54.7800  54.170  54.550   8288841
# 2015-12-29  32.4400   6388244  55.290  55.3500  54.990  55.110   7894876
# 2015-12-30  32.5000   5057162  54.890  55.3100  54.794  55.270   8016893
# 2015-12-31  31.9100   8149307  54.360  54.9499  54.220  54.510  10929567
# 2016-01-01  31.8100         0  54.360  54.3600  54.360  54.360         0
#
# [2610 rows x 30 columns]

# %% [markdown]
# ** Defina os níveis dos nomes das colunas (este está preenchido para você): **

# %%
bank_stocks.columns.names = ['Bank Ticker','Stock Info']

# %% [markdown]
# ** Verifique o cabeçalho do DataFrame bank_stocks. **

# %%
bank_stocks.head()
# Out:
# Bank Ticker    BAC                                     C                       \
# Stock Info   Close   High    Low   Open    Volume  Close   High    Low   Open
# Date
# 2006-01-02   46.15  46.36  45.91  46.02         0  485.3  487.1  482.2  483.5
# 2006-01-03   47.08  47.18  46.15  46.92  16197900  492.9  493.8  481.1  490.0
# 2006-01-04   46.58  47.24  46.45  47.00  17427400  483.8  491.0  483.5  488.6
# 2006-01-05   46.64  46.83  46.32  46.58  14668900  486.2  487.8  484.0  484.4
# 2006-01-06   46.57  46.91  46.35  46.80  11965700  486.2  489.0  482.0  488.8
#
# Bank Ticker             ...          MS                                      \
# Stock Info    Volume    ...       Close     High      Low     Open   Volume
# Date                    ...
# 2006-01-02         0    ...     47.1008  47.3333  46.7107  47.2751        0
# 2006-01-03   1536700    ...     48.4041  48.5535  47.1008  47.4578  6354408
# 2006-01-04   1852790    ...     48.4373  49.2093  48.4373  48.7278  9292188
# 2006-01-05   1015470    ...     48.5701  48.6365  48.1634  48.6033  6534262
# 2006-01-06   1358930    ...     48.6199  48.8524  48.1883  48.7860  8146445
#
# Bank Ticker     WFC
# Stock Info    Close    High     Low    Open    Volume
# Date
# 2006-01-02   31.415  31.535  31.215  31.415         0
# 2006-01-03   31.900  31.975  31.195  31.600  11015000
# 2006-01-04   31.530  31.820  31.365  31.800  10594000
# 2006-01-05   31.495  31.555  31.310  31.500   9927600
# 2006-01-06   31.680  31.775  31.385  31.580   8324000
#
# [5 rows x 30 columns]

# %%
# Out:
# Bank Ticker    BAC                                     C                       \
# Stock Info    Open   High    Low  Close    Volume   Open   High    Low  Close
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.0  493.8  481.1  492.9
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.6  491.0  483.5  483.8
# 2006-01-05   46.58  46.83  46.32  46.64  14970900  484.4  487.8  484.0  486.2
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  488.8  489.0  482.0  486.2
# 2006-01-09   46.72  46.97  46.36  46.60  15620000  486.0  487.4  483.0  483.9
#
# Bank Ticker             ...        MS                                  WFC  \
# Stock Info    Volume    ...      Open   High    Low  Close   Volume   Open
# Date                    ...
# 2006-01-03   1537660    ...     57.17  58.49  56.74  58.31  5377000  31.60
# 2006-01-04   1871020    ...     58.70  59.28  58.35  58.35  7977800  31.80
# 2006-01-05   1143160    ...     58.55  58.59  58.02  58.51  5778000  31.50
# 2006-01-06   1370250    ...     58.77  58.85  58.05  58.57  6889800  31.58
# 2006-01-09   1680740    ...     58.63  59.29  58.62  59.19  4144500  31.68
#
# Bank Ticker
# Stock Info    High    Low  Close    Volume
# Date
# 2006-01-03   31.98  31.20  31.90  11016400
# 2006-01-04   31.82  31.36  31.53  10871000
# 2006-01-05   31.56  31.31  31.50  10158000
# 2006-01-06   31.78  31.38  31.68   8403800
# 2006-01-09   31.82  31.56  31.68   5619600
#
# [5 rows x 30 columns]

# %% [markdown]
# # Análise de dados exploratória
#
# Vamos explorar os dados um pouco! Antes de prosseguir, sugiro que você verifique a documentação no [Multi-Level Indexing](http://pandas.pydata.org/pandas-docs/stable/advanced.html) e [como usar .xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html).
# Consulte as soluções se você não consiga descobrir como usar .xs (), uma vez que isso será uma parte importante desse projeto.
#
# ** Qual é o preço máximo de fechamento para cada banco durante todo o período? **

# %%
bank_stocks.xs('Close', axis=1, level='Stock Info').idxmax()
# Out:
# Bank Ticker
# BAC   2006-11-16
# C     2006-12-27
# GS    2007-10-31
# JPM   2015-07-22
# MS    2007-06-14
# WFC   2015-07-22
# dtype: datetime64[ns]

# %%
bank_stocks.xs('Close', axis=1, level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     54.9000
# C      564.1000
# GS     247.9200
# JPM     70.0800
# MS      74.1294
# WFC     58.5200
# dtype: float64

# %% [markdown]
# ** Crie um novo DataFrame vazio chamado returns. Este dataframe conterá os retornos para o ação de cada banco. Os retornos geralmente são definidos por: **
#
# $$r_t = \frac{p_t - p_{t-1}}{p_{t-1}} = \frac{p_t}{p_{t-1}} - 1$$

# %%
returns = pd.DataFrame()

# %% [markdown]
# ** Podemos usar o método pct_change () pandas na coluna close para criar uma coluna que represente esse valor de retorno. Crie um loop for que vá e para cada Bank Stock Ticker cria essa coluna de retorno e configura-a como uma coluna nos dados DataFrame. **

# %%
for tick in tickers:
    returns['{} Return'.format(tick)] = bank_stocks[tick]['Close'].pct_change()
returns.head(6)
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-02         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-03    0.020152  0.015660   0.009083    0.012598   0.027670    0.015438
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.001110
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005874
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586   -0.000158

# %%
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.000951
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005714
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586    0.000000

# %% [markdown]
# ** Crie um parplot utilizando seaborn no dataframe de retorno. **

# %%
sns.pairplot(returns[1:])

# %% [markdown]
# ** Usando o seu DataFrame returns, descubra quais datas cada ação dos bancos teve o melhor e o pior dia de retorno. Você deve notar que 4 dos bancos compartilham o mesmo dia para a pior queda. Alguma coisa significante aconteceu naquele dia? **

# %% [markdown]
# **Melhor dia de retorno**

# %%
returns.idxmax()
# Out:
# BAC returns   2009-04-09
# C returns     2008-11-24
# GS returns    2008-11-24
# JPM returns   2009-01-21
# MS returns    2008-10-13
# WFC returns   2008-07-16
# dtype: datetime64[ns]

# %% [markdown]
# **Pior dia de retorno**

# %%
returns.idxmin()
# Out:
# BAC returns   2009-01-20
# C returns     2009-02-27
# GS returns    2009-01-20
# JPM returns   2009-01-20
# MS returns    2008-10-09
# WFC returns   2009-01-20
# dtype: datetime64[ns]

# %% [markdown]
# ** Dê uma olhada no desvio padrão dos retornos. Qual ação você classificaria como a mais arriscada durante todo o período de tempo? Qual você classificaria como a mais arriscado para o ano 2015? **

# %%
returns.std()
# Out:
# BAC Return    0.035987
# C Return      0.037977
# GS Return     0.024950
# JPM Return    0.027223
# MS Return     0.037043
# WFC Return    0.029697
# dtype: float64

# %%
# Out:
# BAC Return    0.036650
# C Return      0.179969
# GS Return     0.025346
# JPM Return    0.027656
# MS Return     0.037820
# WFC Return    0.030233
# dtype: float64

# %%
returns.loc['2015-01-01':'2015-12-31'].std().sort_values()
# Out:
# WFC Return    0.012372
# JPM Return    0.013772
# GS Return     0.013801
# C Return      0.015022
# BAC Return    0.015880
# MS Return     0.015966
# dtype: float64

# %%
# Out:
# BAC Return    0.016163
# C Return      0.015289
# GS Return     0.014046
# JPM Return    0.014017
# MS Return     0.016249
# WFC Return    0.012591
# dtype: float64

# %% [markdown]
# ** Crie um distplot usando seaborn dos retornos de 2015 para Morgan Stanley **

# %%
sns.distplot(returns.loc['2015-01-01':'2015-12-31']['MS Return'], bins=100, color='g')
# Out:
# /home/jonatasleon/.virtualenvs/jupyter/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
# Out:
# /Users/marci/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning:
#
# using a non-integer number instead of an integer will result in an error in the future

# %% [markdown]
# ** Crie um distplot usando seaborn dos retornos de 2008 para CitiGroup **

# %%
sns.distplot(returns.loc['2008-01-01':'2008-12-31']['C Return'], bins=110, color='r')
# Out:
# /home/jonatasleon/.virtualenvs/jupyter/lib/python3.5/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
# Out:
# /Users/marci/anaconda/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning:
#
# using a non-integer number instead of an integer will result in an error in the future

# %% [markdown]
# # Mais visualização
#
# Muito desse projeto se concentrará em visualizações. Sinta-se livre para usar qualquer uma das suas bibliotecas de visualização preferidas para tentar recriar os plots descritos abaixo, seaborn, matplotlib, plotly e cufflinks, ou apenas pandas.
#
# ### Importações

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %% [markdown]
# ** Crie um gráfico de linha mostrando o preço de fechamento para cada banco para todo o índice de tempo. (Sugestão: tente usar um loop for ou use [.xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html) para obter uma seção transversal dos dados .) **

# %%
for tick in tickers:
    bank_stocks[tick]['Close'].plot(figsize=(12, 4), label=tick)
plt.legend()

# %%
bank_stocks.xs(key='Close', level='Stock Info', axis=1).plot(figsize=(12, 4))

# %% [markdown]
# ## Médias móveis
#
# Vamos analisar as médias móveis para essas ações no ano de 2008.
#
# ** Trace a média de 30 dias para o preço do Bank Of America para o ano de 2008 **

# %%
BAC2008 = BAC['Close'][BAC.index.year == 2008]
BAC2008_media_movel = BAC2008.rolling(window=30).mean()
BAC2008_media_movel.plot(label='Média Movel', figsize=(12, 4))
BAC2008.plot(label='Fechamento')
plt.legend()

# %% [markdown]
# ** Crie um mapa de calor da correlação entre os preços de fechamento das ações. **

# %%
bank_stocks.head()
# Out:
# Bank Ticker    BAC                                     C                       \
# Stock Info   Close   High    Low   Open    Volume  Close   High    Low   Open
# Date
# 2006-01-02   46.15  46.36  45.91  46.02         0  485.3  487.1  482.2  483.5
# 2006-01-03   47.08  47.18  46.15  46.92  16197900  492.9  493.8  481.1  490.0
# 2006-01-04   46.58  47.24  46.45  47.00  17427400  483.8  491.0  483.5  488.6
# 2006-01-05   46.64  46.83  46.32  46.58  14668900  486.2  487.8  484.0  484.4
# 2006-01-06   46.57  46.91  46.35  46.80  11965700  486.2  489.0  482.0  488.8
#
# Bank Ticker             ...          MS                                      \
# Stock Info    Volume    ...       Close     High      Low     Open   Volume
# Date                    ...
# 2006-01-02         0    ...     47.1008  47.3333  46.7107  47.2751        0
# 2006-01-03   1536700    ...     48.4041  48.5535  47.1008  47.4578  6354408
# 2006-01-04   1852790    ...     48.4373  49.2093  48.4373  48.7278  9292188
# 2006-01-05   1015470    ...     48.5701  48.6365  48.1634  48.6033  6534262
# 2006-01-06   1358930    ...     48.6199  48.8524  48.1883  48.7860  8146445
#
# Bank Ticker     WFC
# Stock Info    Close    High     Low    Open    Volume
# Date
# 2006-01-02   31.415  31.535  31.215  31.415         0
# 2006-01-03   31.900  31.975  31.195  31.600  11015000
# 2006-01-04   31.530  31.820  31.365  31.800  10594000
# 2006-01-05   31.495  31.555  31.310  31.500   9927600
# 2006-01-06   31.680  31.775  31.385  31.580   8324000
#
# [5 rows x 30 columns]

# %%
sns.heatmap(bank_stocks.xs(key='Close', axis=1, level='Stock Info').corr(), cmap='viridis_r', annot=True)

# %% [markdown]
# ** Opcional: use o clustermap do seaborn para agrupar as correlações: **

# %%
sns.clustermap(bank_stocks.xs(key='Close', axis=1, level='Stock Info').corr(), cmap='viridis_r', annot=True)

# %% [markdown]
# Definitivamente, muitos tópicos de finanças específicos aqui, então não se preocupe se você não os entendeu todos! A única coisa que você deve estar preocupado com a compreensão são os pandas básicos e operações de visualização.
